# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/notebooks'
# Colab Notebooks 안에 my_env 폴더에 패키지 저장
os.symlink('/content/drive/My Drive/Colab Notebooks/my_env', my_path)
sys.path.insert(0, my_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-1-6d89b7b51fbe> in <module>()
#       5 my_path = '/content/notebooks'
#       6 # Colab Notebooks 안에 my_env 폴더에 패키지 저장
# ----> 7 os.symlink('/content/drive/My Drive/Colab Notebooks/my_env', my_path)
#       8 sys.path.insert(0, my_path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/My Drive/Colab Notebooks/my_env' -> '/content/notebooks'

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (0.15.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.12.0)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.18.4)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

import warnings; warnings.simplefilter('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
md = pd. read_csv('/content/drive/My Drive/Colab Notebooks/MovieRcmmd/data/data/movies_metadata.csv')
md.head()
# Out:
#    adult  ... vote_count
# 0  False  ...     5415.0
# 1  False  ...     2413.0
# 2  False  ...       92.0
# 3  False  ...       34.0
# 4  False  ...      173.0
#
# [5 rows x 24 columns]

# %%
md['genres'][0] # 각 행들의 구조가 "{'id':_,'name':'_'},{'id';_,'name':'_'}, ,,,"
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
print(type(md['genres'][0])) # dict들이 str으로 묶여있음
md['genres'].apply(literal_eval) #[{dict},{dict}] <- str을 list로 바꿔줌
# Out:
# <class 'str'>
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
#각 영화 장르의 이름을 추출해 list 시켜줌
md['genres'] = md['genres'].fillna('[]').apply(literal_eval).apply(lambda x : [i['name'] for i in x] if isinstance(x, list) else [])

# %%
md['genres']
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
# eval(expression, globals=None, locals=none), 내장함수
# expression 인자에 string 값을 넣으면 해당 값을 그대로 실행하여 결과를 출력
expr = "10 + 10"
print(type(expr))
print(eval(expr))
# Out:
# <class 'str'>
# 20

# %%
#ast.literal_eval(node_or_string), AST module에서 제공하는 함수
#문자 그대로 evaluate 실행하는 함수
import ast
str_dict = "{'a':3,'b':5}"
print(type(str_dict))
convert_dict= ast.literal_eval(str_dict)
print(convert_dict['a'])
print(convert_dict['b'])
# Out:
# <class 'str'>
# 3
# 5

# %%
#literal_eval은 ValueError를 발생시킬 수 있다.
ast.literal_eval("10*2")
#literal_eval은 python의 기본 자료형 정도만 evaluate가 가능하도록 지원. eval과 비교해 훨씬 엄격하기 때문에 결과적으로 안전을 보장.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4cf8fba2f0b9> in <module>()
#       1 #literal_eval은 ValueError를 발생시킬 수 있다.
# ----> 2 ast.literal_eval("10*2")
#       3 #literal_eval은 python의 기본 자료형 정도만 evaluate가 가능하도록 지원. eval과 비교해 훨씬 엄격하기 때문에 결과적으로 안전을 보장.
#
# /usr/lib/python3.6/ast.py in literal_eval(node_or_string)
#      83                     return left - right
#      84         raise ValueError('malformed node or string: ' + repr(node))
# ---> 85     return _convert(node_or_string)
#      86
#      87
#
# /usr/lib/python3.6/ast.py in _convert(node)
#      82                 else:
#      83                     return left - right
# ---> 84         raise ValueError('malformed node or string: ' + repr(node))
#      85     return _convert(node_or_string)
#      86
#
# ValueError: malformed node or string: <_ast.BinOp object at 0x7f4637fab7b8>

# %%
type(md['vote_count'][0]) #vote_count의 타입이 float
# Out:
# numpy.float64

# %%
vote_counts = md[md['vote_count'].notnull()]['vote_count'].astype('int') #float을 int로
vote_averages = md[md['vote_average'].notnull()]['vote_average'].astype('int')
C = vote_averages.mean()
C
# Out:
# 5.244896612406511

# %%
m = vote_counts.quantile(0.95)
m
# Out:
# 434.0

# %%
md['year'] = pd.to_datetime(md['release_date'], errors='coerce').apply(lambda x : str(x).split('-')[0] if x != np.nan else np.nan)
# error='coerce'
# 날짜로 된 문자열이 아니라 문자로 된 문자열인 경우 파싱할 수 없다는 ValueError가 발생하는 것을 방지하기 위해 'coerce'옵션 추가
# 파싱할 수 없는 문자열은 'NaN'으로 강제 변환

# %%
md['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45461     NaT
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: year, Length: 45466, dtype: object

# %%
qualified = md[(md['vote_count'] >= m) & (md['vote_count'].notnull()) & (md['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity', 'genres']]
qualified['vote_count'] = qualified['vote_count'].astype('int')
qualified['vote_average'] = qualified['vote_average'].astype('int')
qualified.shape #(행 수, 열 수)
# Out:
# (2274, 6)

# %%
def weighted_rating(x):
  v = x['vote_count']
  R = x['vote_average']
  return (v/(v+m)*R)+(m/(m+v)*C) # Weighted Rating(WR)
# v is the number of votes for the movie
# m is the minimum votes required to be listed in the chart
# R is the average rating of the movie
# C is the mean vote across the whole report

# %%
qualified['wr'] = qualified.apply(weighted_rating, axis=1)

# %%
qualified = qualified.sort_values('wr', ascending=False).head(250)

# %%
qualified['wr']
# Out:
# 15480    7.917588
# 12481    7.905871
# 22879    7.897107
# 2843     7.881753
# 4863     7.871787
#            ...
# 2006     6.767415
# 16129    6.765698
# 895      6.763480
# 9888     6.761143
# 16833    6.760918
# Name: wr, Length: 250, dtype: float64

# %%
qualified.head(15)
# Out:
#                                                    title  ...        wr
# 15480                                          Inception  ...  7.917588
# 12481                                    The Dark Knight  ...  7.905871
# 22879                                       Interstellar  ...  7.897107
# 2843                                          Fight Club  ...  7.881753
# 4863   The Lord of the Rings: The Fellowship of the Ring  ...  7.871787
# 292                                         Pulp Fiction  ...  7.868660
# 314                             The Shawshank Redemption  ...  7.864000
# 7000       The Lord of the Rings: The Return of the King  ...  7.861927
# 351                                         Forrest Gump  ...  7.860656
# 5814               The Lord of the Rings: The Two Towers  ...  7.851924
# 256                                            Star Wars  ...  7.834205
# 1225                                  Back to the Future  ...  7.820813
# 834                                        The Godfather  ...  7.814847
# 1154                             The Empire Strikes Back  ...  7.814099
# 46                                                 Se7en  ...  7.811669
#
# [15 rows x 7 columns]

# %%
md.apply(lambda x : pd.Series(x['genres']), axis=1)
# Out:
#                0        1         2    3    4    5    6    7
# 0      Animation   Comedy    Family  NaN  NaN  NaN  NaN  NaN
# 1      Adventure  Fantasy    Family  NaN  NaN  NaN  NaN  NaN
# 2        Romance   Comedy       NaN  NaN  NaN  NaN  NaN  NaN
# 3         Comedy    Drama   Romance  NaN  NaN  NaN  NaN  NaN
# 4         Comedy      NaN       NaN  NaN  NaN  NaN  NaN  NaN
# ...          ...      ...       ...  ...  ...  ...  ...  ...
# 45461      Drama   Family       NaN  NaN  NaN  NaN  NaN  NaN
# 45462      Drama      NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 45463     Action    Drama  Thriller  NaN  NaN  NaN  NaN  NaN
# 45464        NaN      NaN       NaN  NaN  NaN  NaN  NaN  NaN
# 45465        NaN      NaN       NaN  NaN  NaN  NaN  NaN  NaN
#
# [45466 rows x 8 columns]

# %%
md.apply(lambda x : pd.Series(x['genres']), axis=1).stack()
# Out:
# 0      0    Animation
#        1       Comedy
#        2       Family
# 1      0    Adventure
#        1      Fantasy
#               ...
# 45461  1       Family
# 45462  0        Drama
# 45463  0       Action
#        1        Drama
#        2     Thriller
# Length: 91106, dtype: object

# %%
s = md.apply(lambda x : pd.Series(x['genres']), axis=1).stack().reset_index(level=1, drop=True)
# 인덱스 1단계 제거(첫번째 열)
s
# Out:
# 0        Animation
# 0           Comedy
# 0           Family
# 1        Adventure
# 1          Fantasy
#            ...
# 45461       Family
# 45462        Drama
# 45463       Action
# 45463        Drama
# 45463     Thriller
# Length: 91106, dtype: object

# %%
s.name = 'genre'
gen_md = md.drop('genres', axis = 1).join(s)
gen_md
# Out:
#        adult  ...      genre
# 0      False  ...  Animation
# 0      False  ...     Comedy
# 0      False  ...     Family
# 1      False  ...  Adventure
# 1      False  ...    Fantasy
# ...      ...  ...        ...
# 45463  False  ...     Action
# 45463  False  ...      Drama
# 45463  False  ...   Thriller
# 45464  False  ...        NaN
# 45465  False  ...        NaN
#
# [93548 rows x 25 columns]

# %%
def build_chart(genre, percentile=0.86):
  df = gen_md[gen_md['genre'] == genre]
  vote_counts = df[df['vote_count'].notnull()]['vote_count'].astype('int')
  vote_averages = df[df['vote_average'].notnull()]['vote_average'].astype('int')
  C = vote_averages.mean()
  m = vote_counts.quantile(percentile)

# 여러 개의 칼럼 데이터 추추 시 대괄호 두번[[]]
  qualified = df[(df['vote_count'] >= m) & (df['vote_count'].notnull()) & (df['vote_average'].notnull())][['title', 'year', 'vote_count', 'vote_average', 'popularity']]
  qualified['vote_count'] = qualified['vote_count'].astype('int')
  qualified['vote_average'] = qualified['vote_average'].astype('int')

  qualified['wr'] = qualified.apply(lambda x: (x['vote_count']/(x['vote_count']+m)*x['vote_average'])+(m/(m+x['vote_count'])*C), axis=1)
  qualified = qualified.sort_values('wr', ascending=False).head(250)

  return qualified

# %% [markdown]
# Top Romance Movies

# %%
build_chart('Romance').head(15)
# Out:
#                              title  year  ...  popularity        wr
# 10309  Dilwale Dulhania Le Jayenge  1995  ...      34.457  8.518318
# 351                   Forrest Gump  1994  ...     48.3072  7.967827
# 876                        Vertigo  1958  ...     18.2082  7.790072
# 40251                   Your Name.  2016  ...   34.461252  7.765598
# 883               Some Like It Hot  1959  ...     11.8451  7.716829
# 1132               Cinema Paradiso  1988  ...      14.177  7.716527
# 19901                     Paperman  2012  ...     7.19863  7.682628
# 37863                  Sing Street  2016  ...   10.672862  7.655880
# 882                  The Apartment  1960  ...     11.9943  7.557845
# 38718               The Handmaiden  2016  ...   16.727405  7.522010
# 3189                   City Lights  1931  ...     10.8915  7.514135
# 24886             The Way He Looks  2014  ...     5.71127  7.271362
# 1639                       Titanic  1997  ...     26.8891  6.979274
# 19731      Silver Linings Playbook  2012  ...     14.4881  6.966987
# 40882                   La La Land  2016  ...   19.681686  6.966340
#
# [15 rows x 6 columns]

# %%
links_small = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MovieRcmmd/data/data/links_small.csv')
links_small
# imdbid : internet movie data base
# tmdbid : the movie data base
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %%
links_small = links_small[links_small['tmdbId'].notnull()]['tmdbId'].astype('int')
links_small
# Out:
# 0          862
# 1         8844
# 2        15602
# 3        31357
# 4        11862
#          ...
# 9120    402672
# 9121    315011
# 9122    391698
# 9123    137608
# 9124    410803
# Name: tmdbId, Length: 9112, dtype: int64

# %%
# 여러 개의 행 추출 시 대괄호 두 번 [[]]
md.loc[[19730, 29503, 35587]] #id가 날짜 형식
# Out:
#                                                    adult  ... year
# 19730                                 - Written by Ørnås  ...  NaT
# 29503   Rune Balot goes to a casino connected to the ...  ...  NaT
# 35587   Avalanche Sharks tells the story of a bikini ...  ...  NaT
#
# [3 rows x 25 columns]

# %%
md = md.drop([19730, 29503, 35587])

# %%
md['id'] = md['id'].astype('int')

# %%
smd = md[md['id'].isin(links_small)]
smd.shape
# Out:
# (9099, 25)

# %%
smd.loc[1]['title']
# Out:
# 'Jumanji'

# %%
smd.loc[1]['overview'] # overview : 개요
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
smd.loc[1]['tagline'] # tagline : 광고 구호, 슬로건
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
smd['tagline'] = smd['tagline'].fillna('')
smd['description'] = smd['overview'] + smd['tagline']
smd['description'] = smd['description'].fillna('')

# %%
# tf-idf 인코딩 : 단어 갯수 그대로 카운트하지 않고 모든 문서에 공통적으로 들어있는 단어의 경우 문서 구별 능력이 떨어진다고 보아 가중치를 축소하는 방법
# analyzer='word'/'char'/'char_wb'(단어 내의 문자)
# ngram_range=(min_n, max_n)
# min_df=[0.0,1.0]사이의 실수. 디폴트 1, 단어장에 포함되기 위한 최소 빈도
# stop_words='english' : 영어용 스탑 워드 사용
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(smd['description'])

# %%
tf.vocabulary_ # 단어를 인덱싱, type은 dict
# Out:
# {'led': 136477,
#  'woody': 263021,
#  'andy': 10545,
#  'toys': 242493,
#  'live': 140882,
#  'happily': 106340,
#  'room': 203269,
#  'birthday': 24045,
#  'brings': 29222,
#  'buzz': 32147,
#  'lightyear': 139593,
#  'scene': 207235,
#  'afraid': 6268,
#  'losing': 143903,
#  'place': 180436,
#  'heart': 108234,
#  'plots': 182226,
#  'circumstances': 40897,
#  'separate': 211425,
#  'owner': 173335,
#  'duo': 70725,
#  'eventually': 78024,
#  'learns': 135993,
#  'aside': 14372,
#  'differences': 63703,
#  'led woody': 136575,
#  'woody andy': 263023,
#  'andy toys': 10578,
#  'toys live': 242500,
#  'live happily': 140969,
#  'happily room': 106359,
#  'room andy': 203273,
#  'andy birthday': 10548,
#  'birthday brings': 24049,
#  'brings buzz': 29230,
#  'buzz lightyear': 32153,
#  'lightyear scene': 139595,
#  'scene afraid': 207239,
#  'afraid losing': 6282,
#  'losing place': 143950,
#  'place andy': 180445,
#  'andy heart': 10561,
#  'heart woody': 108388,
#  'woody plots': 263030,
#  'plots buzz': 182227,
#  'buzz circumstances': 32149,
#  'circumstances separate': 40915,
#  'separate buzz': 211426,
#  'buzz woody': 32156,
#  'woody owner': 263028,
#  'owner duo': 173370,
#  'duo eventually': 70735,
#  'eventually learns': 78094,
#  'learns aside': 135999,
#  'aside differences': 14374,
#  'siblings': 215390,
#  'judy': 127863,
#  'peter': 178843,
#  'discover': 64992,
#  'enchanted': 74263,
#  'board': 25452,
#  'game': 95889,
#  'opens': 171065,
#  'door': 68082,
#  'magical': 147117,
#  'world': 263896,
#  'unwittingly': 250401,
#  'invite': 122532,
#  'alan': 7739,
#  'adult': 5333,
#  'trapped': 243569,
#  'inside': 120382,
#  '26': 1880,
#  'years': 266138,
#  'living': 141637,
#  'hope': 113350,
#  'freedom': 93087,
#  'finish': 88661,
#  'proves': 188800,
#  'risky': 201326,
#  'running': 204507,
#  'giant': 98375,
#  'rhinoceroses': 200199,
#  'evil': 78310,
#  'monkeys': 159144,
#  'terrifying': 236702,
#  'creatures': 52652,
#  'roll': 202697,
#  'dice': 63269,
#  'unleash': 249558,
#  'excitement': 78986,
#  'siblings judy': 215396,
#  'judy peter': 127878,
#  'peter discover': 178857,
#  'discover enchanted': 65049,
#  'enchanted board': 74264,
#  'board game': 25465,
#  'game opens': 96008,
#  'opens door': 171079,
#  'door magical': 68114,
#  'magical world': 147166,
#  'world unwittingly': 264623,
#  'unwittingly invite': 250413,
#  'invite alan': 122533,
#  'alan adult': 7740,
#  'adult trapped': 5363,
#  'trapped inside': 243593,
#  'inside game': 120414,
#  'game 26': 95890,
#  '26 years': 1887,
#  'years living': 266346,
#  'living room': 141817,
#  'room alan': 203272,
#  'alan hope': 7754,
#  'hope freedom': 113383,
#  'freedom finish': 93111,
#  'finish game': 88671,
#  'game proves': 96020,
#  'proves risky': 188834,
#  'risky running': 201333,
#  'running giant': 204525,
#  'giant rhinoceroses': 98421,
#  'rhinoceroses evil': 200200,
#  'evil monkeys': 78465,
#  'monkeys terrifying': 159148,
#  'terrifying creatures': 236713,
#  'creatures roll': 52702,
#  'roll dice': 202703,
#  'dice unleash': 63270,
#  'unleash excitement': 249563,
#  'family': 82306,
#  'wedding': 258408,
#  'reignites': 195598,
#  'ancient': 10312,
#  'feud': 85999,
#  'neighbors': 165461,
#  'fishing': 88969,
#  'buddies': 30705,
#  'john': 126524,
#  'max': 152389,
#  'sultry': 230358,
#  'italian': 123642,
#  'divorcée': 66549,
#  'restaurant': 198491,
#  'local': 142139,
#  'bait': 18138,
#  'shop': 214654,
#  'alarming': 7772,
#  'locals': 142347,
#  'worry': 264783,
#  'll': 141921,
#  'scare': 207132,
#  'fish': 88919,
#  'away': 17083,
#  'interested': 121325,
#  'seafood': 208796,
#  'cooking': 49619,
#  'hot': 114214,
#  'time': 239488,
#  'yelling': 266525,
#  'fighting': 86625,
#  'ready': 193033,
#  'love': 144424,
#  'family wedding': 82992,
#  'wedding reignites': 258468,
#  'reignites ancient': 195599,
#  'ancient feud': 10338,
#  'feud door': 86002,
#  'door neighbors': 68118,
#  'neighbors fishing': 165472,
#  'fishing buddies': 88972,
#  'buddies john': 30721,
#  'john max': 126658,
#  'max sultry': 152459,
#  'sultry italian': 230363,
#  'italian divorcée': 123657,
#  'divorcée opens': 66552,
#  'opens restaurant': 171095,
#  'restaurant local': 198517,
#  'local bait': 142152,
#  'bait shop': 18142,
#  'shop alarming': 214656,
#  'alarming locals': 7776,
#  'locals worry': 142365,
#  'worry ll': 264792,
#  'll scare': 142012,
#  'scare fish': 207137,
#  'fish away': 88921,
#  'away interested': 17172,
#  'interested seafood': 121345,
#  'seafood cooking': 208797,
#  'cooking hot': 49625,
#  'hot time': 114254,
#  'time max': 239865,
#  'max yelling': 152471,
#  'yelling fighting': 266526,
#  'fighting ready': 86697,
#  'ready love': 193075,
#  'cheated': 38652,
#  'mistreated': 157932,
#  'stepped': 225245,
#  'women': 262450,
#  'holding': 111987,
#  'breath': 28599,
#  'waiting': 255123,
#  'elusive': 73399,
#  'good': 101090,
#  'man': 148481,
#  'break': 28352,
#  'string': 228002,
#  'stellar': 225113,
#  'lovers': 145427,
#  'friends': 93940,
#  'confidants': 47398,
#  'vannah': 251817,
#  'bernie': 22657,
#  'glo': 99928,
#  'robin': 202103,
#  'talk': 234004,
#  'determined': 62472,
#  'better': 23085,
#  'way': 257361,
#  'breathe': 28605,
#  'people': 177471,
#  'let': 137596,
#  'forget': 91618,
#  'cheated mistreated': 38656,
#  'mistreated stepped': 157936,
#  'stepped women': 225250,
#  'women holding': 262561,
#  'holding breath': 111991,
#  'breath waiting': 28604,
#  'waiting elusive': 255138,
#  'elusive good': 73403,
#  'good man': 101165,
#  'man break': 148569,
#  'break string': 28437,
#  'string stellar': 228012,
#  'stellar lovers': 225115,
#  'lovers friends': 145440,
#  'friends confidants': 94014,
#  'confidants vannah': 47399,
#  'vannah bernie': 251818,
#  'bernie glo': 22661,
#  'glo robin': 99929,
#  'robin talk': 202124,
#  'talk determined': 234017,
#  'determined better': 62481,
#  'better way': 23154,
#  'way breathe': 257406,
#  'breathe friends': 28607,
#  'friends people': 94243,
#  'people let': 177640,
#  'let let': 137628,
#  'let forget': 137609,
#  'just': 128304,
#  'george': 97452,
#  'banks': 18784,
#  'recovered': 194624,
#  'daughter': 56433,
#  'receives': 194089,
#  'news': 166546,
#  'pregnant': 185081,
#  'wife': 259799,
#  'nina': 167462,
#  'expecting': 79586,
#  'planning': 181144,
#  'selling': 210724,
#  'home': 112362,
#  'plan': 180769,
#  'like': 139602,
#  'change': 37432,
#  'arrival': 13548,
#  'grandchild': 102153,
#  'kid': 129987,
#  'normal': 167867,
#  'surprise': 231333,
#  'life': 138185,
#  'just george': 128441,
#  'george banks': 97461,
#  'banks recovered': 18795,
#  'recovered daughter': 194627,
#  'daughter wedding': 56780,
#  'wedding receives': 258466,
#  'receives news': 194111,
#  'news pregnant': 166590,
#  'pregnant george': 185098,
#  'george wife': 97551,
#  'wife nina': 260112,
#  'nina expecting': 167467,
#  'expecting planning': 79596,
#  'planning selling': 181167,
#  'selling home': 210742,
#  'home plan': 112633,
#  'plan like': 180833,
#  'like george': 139708,
#  'george change': 97467,
#  'change arrival': 37436,
#  'arrival grandchild': 13567,
#  'grandchild kid': 102154,
#  'kid just': 130025,
#  'just world': 128679,
#  'world normal': 264362,
#  'normal surprise': 167908,
#  'surprise life': 231352,
#  'obsessive': 169141,
#  'master': 151693,
#  'thief': 237645,
#  'neil': 165520,
#  'mccauley': 152684,
#  'leads': 135532,
#  'notch': 168132,
#  'crew': 52800,
#  'various': 251883,
#  'insane': 120274,
#  'heists': 108884,
#  'los': 143761,
#  'angeles': 10673,
#  'mentally': 154912,
#  'unstable': 250110,
#  'detective': 62246,
#  'vincent': 253663,
#  'hanna': 105987,
#  'pursues': 189914,
#  'rest': 198436,
#  'recognizes': 194370,
#  'respects': 198337,
#  'ability': 2760,
#  'dedication': 59602,
#  'aware': 17058,
#  'cat': 35538,
#  'mouse': 160709,
#  'end': 74477,
#  'violence': 253746,
#  'crime': 52986,
#  'saga': 205464,
#  'obsessive master': 169145,
#  'master thief': 151784,
#  'thief neil': 237685,
#  'neil mccauley': 165528,
#  'mccauley leads': 152685,
#  'leads notch': 135630,
#  'notch crew': 168133,
#  'crew various': 52946,
#  'various insane': 251915,
#  'insane heists': 120286,
#  'heists los': 108887,
#  'los angeles': 143762,
#  'angeles mentally': 10742,
#  'mentally unstable': 154926,
#  'unstable detective': 250111,
#  'detective vincent': 62367,
#  'vincent hanna': 253677,
#  'hanna pursues': 105992,
#  'pursues rest': 189933,
#  'rest man': 198457,
#  'man recognizes': 149133,
#  'recognizes respects': 194378,
#  'respects ability': 198338,
#  'ability dedication': 2768,
#  'dedication aware': 59603,
#  'aware cat': 17059,
#  'cat mouse': 35568,
#  'mouse game': 160720,
#  'game end': 95934,
#  'end violence': 74666,
#  'violence los': 253784,
#  'angeles crime': 10701,
#  'crime saga': 53109,
#  'ugly': 247505,
#  'duckling': 70482,
#  'having': 107434,
#  'undergone': 248381,
#  'remarkable': 196718,
#  'harbors': 106544,
#  'feelings': 85345,
#  'crush': 54003,
#  'carefree': 34432,
#  'playboy': 181603,
#  'business': 31669,
#  'focused': 90045,
#  'brother': 29883,
#  'say': 206914,
#  'cordially': 50070,
#  'invited': 122543,
#  'surprising': 231392,
#  'merger': 155107,
#  'year': 265897,
#  'ugly duckling': 247510,
#  'duckling having': 70483,
#  'having undergone': 107555,
#  'undergone remarkable': 248383,
#  'remarkable change': 196724,
#  'change harbors': 37469,
#  'harbors feelings': 106547,
#  'feelings crush': 85353,
#  'crush carefree': 54010,
#  'carefree playboy': 34439,
#  'playboy business': 181609,
#  'business focused': 31722,
#  'focused brother': 90047,
#  'brother say': 30070,
#  'say cordially': 206922,
#  'cordially invited': 50071,
#  'invited surprising': 122572,
#  'surprising merger': 231403,
#  'merger year': 155110,
#  'mischievous': 157294,
#  'young': 266929,
#  'boy': 27396,
#  'tom': 240807,
#  'sawyer': 206898,
#  'witnesses': 261655,
#  'murder': 161714,
#  'deadly': 57903,
#  'injun': 119992,
#  'joe': 126348,
#  'huckleberry': 115013,
#  'finn': 88718,
#  'future': 95294,
#  'choose': 40004,
#  'honoring': 113197,
#  'friendship': 94401,
#  'oath': 168838,
#  'town': 241943,
#  'alcoholic': 7946,
#  'accused': 3791,
#  'huck': 115008,
#  'adventures': 5677,
#  'trying': 246006,
#  'retrieve': 199029,
#  'evidence': 78249,
#  'original': 172077,
#  'bad': 17863,
#  'boys': 27851,
#  'mischievous young': 157311,
#  'young boy': 266979,
#  'boy tom': 27651,
#  'tom sawyer': 240893,
#  'sawyer witnesses': 206900,
#  'witnesses murder': 261685,
#  'murder deadly': 161778,
#  'deadly injun': 57952,
#  'injun joe': 119993,
#  'joe tom': 126443,
#  'tom friends': 240840,
#  'friends huckleberry': 94136,
#  'huckleberry finn': 115014,
#  'finn boy': 88720,
#  'boy future': 27490,
#  'future family': 95342,
#  'family tom': 82923,
#  'tom choose': 240822,
#  'choose honoring': 40024,
#  'honoring friendship': 113198,
#  'friendship honoring': 94461,
#  'honoring oath': 113200,
#  'oath town': 168841,
#  'town alcoholic': 241957,
#  'alcoholic accused': 7947,
#  'accused murder': 3804,
#  'murder tom': 161985,
#  'tom huck': 240853,
#  'huck adventures': 115009,
#  'adventures trying': 5750,
#  'trying retrieve': 246126,
#  'retrieve evidence': 199037,
#  'evidence original': 78279,
#  'original bad': 172086,
#  'bad boys': 17877,
#  'international': 121459,
#  'action': 4105,
#  'superstar': 230887,
#  'jean': 125060,
#  'claude': 42205,
#  'van': 251716,
#  'damme': 55300,
#  'teams': 235293,
#  'powers': 184661,
#  'boothe': 26567,
#  'tension': 236412,
#  'packed': 173700,
#  'suspense': 232085,
#  'thriller': 238847,
#  'set': 212106,
#  'drop': 70032,
#  'stanley': 223474,
#  'cup': 54378,
#  'portrays': 183748,
#  'father': 84078,
#  'suddenly': 229885,
#  'taken': 233152,
#  'championship': 37212,
#  'hockey': 111828,
#  'captors': 33839,
#  'demanding': 60448,
#  'billion': 23710,
#  'dollars': 67583,
#  'frantically': 92765,
#  'sets': 212426,
#  'motion': 160446,
#  'rescue': 197707,
#  'abort': 2917,
#  'impending': 117827,
#  'explosion': 80286,
#  'final': 87740,
#  'buzzer': 32159,
#  'terror': 236799,
#  'goes': 100350,
#  'overtime': 173213,
#  'international action': 121460,
#  'action superstar': 4195,
#  'superstar jean': 230896,
#  'jean claude': 125066,
#  'claude van': 42216,
#  'van damme': 251723,
#  'damme teams': 55305,
#  'teams powers': 235325,
#  'powers boothe': 184668,
#  'boothe tension': 26568,
#  'tension packed': 236425,
#  'packed suspense': 173719,
#  'suspense thriller': 232100,
#  'thriller set': 238895,
#  'set drop': 212208,
#  'drop stanley': 70043,
#  'stanley cup': 223480,
#  'cup game': 54384,
#  'game van': 96066,
#  'damme portrays': 55304,
#  'portrays father': 183752,
#  'father daughter': 84190,
#  'daughter suddenly': 56742,
#  'suddenly taken': 229955,
#  'taken championship': 233174,
#  'championship hockey': 37221,
#  'hockey game': 111832,
#  'game captors': 95907,
#  'captors demanding': 33843,
#  'demanding billion': 60450,
#  'billion dollars': 23714,
#  'dollars game': 67589,
#  'end van': 74662,
#  'damme frantically': 55302,
#  'frantically sets': 92767,
#  'sets plan': 212506,
#  'plan motion': 180851,
#  'motion rescue': 160462,
#  'rescue daughter': 197726,
#  'daughter abort': 56439,
#  'abort impending': 2918,
#  'impending explosion': 117834,
#  'explosion final': 80290,
#  'final buzzer': 87754,
#  'buzzer terror': 32160,
#  'terror goes': 236820,
#  'goes overtime': 100500,
#  'james': 124374,
#  'bond': 26130,
#  'unmask': 249765,
#  'mysterious': 163010,
#  'head': 107739,
#  'janus': 124675,
#  'syndicate': 232875,
#  'prevent': 185879,
#  'leader': 135306,
#  'utilizing': 251229,
#  'goldeneye': 100940,
#  'weapons': 258176,
#  'inflict': 119580,
#  'devastating': 62675,
#  'revenge': 199725,
#  'britain': 29364,
#  'limits': 140104,
#  'fears': 85035,
#  'substitutes': 229440,
#  'james bond': 124382,
#  'bond unmask': 26223,
#  'unmask mysterious': 249768,
#  'mysterious head': 163111,
#  'head janus': 107802,
#  'janus syndicate': 124676,
#  'syndicate prevent': 232882,
#  'prevent leader': 185911,
#  'leader utilizing': 135417,
#  'utilizing goldeneye': 251230,
#  'goldeneye weapons': 100941,
#  'weapons inflict': 258193,
#  'inflict devastating': 119581,
#  'devastating revenge': 62688,
#  'revenge britain': 199739,
#  'britain limits': 29378,
#  'limits fears': 140111,
#  'fears substitutes': 85063,
#  'widowed': 259711,
#  'president': 185549,
#  'andrew': 10484,
#  'shepherd': 213976,
#  'powerful': 184517,
#  'men': 154477,
#  'wants': 255905,
#  'covets': 51806,
#  'sydney': 232767,
#  'ellen': 73227,
#  'wade': 254988,
#  'washington': 256936,
#  'lobbyist': 142127,
#  'attempts': 15707,
#  'courting': 51582,
#  'spark': 221296,
#  'wild': 260302,
#  'rumors': 204257,
#  'decimate': 59409,
#  'approval': 12513,
#  'ratings': 192601,
#  'thing': 237762,
#  'widowed president': 259727,
#  'president andrew': 185555,
#  'andrew shepherd': 10509,
#  'shepherd world': 213982,
#  'world powerful': 264425,
#  'powerful men': 184597,
#  'men wants': 154810,
#  'wants covets': 255952,
#  'covets sydney': 51809,
#  'sydney ellen': 232769,
#  'ellen wade': 73255,
#  'wade washington': 255009,
#  'washington lobbyist': 256956,
#  'lobbyist shepherd': 142130,
#  'shepherd attempts': 213978,
#  'attempts courting': 15732,
#  'courting spark': 51585,
#  'spark wild': 221301,
#  'wild rumors': 260369,
#  'rumors decimate': 204261,
#  'decimate approval': 59410,
#  'approval ratings': 12515,
#  'ratings powerful': 192607,
#  'powerful man': 184592,
#  'man world': 149397,
#  'world thing': 264587,
#  'thing wants': 237880,
#  'lawyer': 135003,
#  'shows': 215097,
#  'vampire': 251610,
#  'doorstep': 68154,
#  'falls': 82004,
#  'prey': 185995,
#  'charms': 38413,
#  'joins': 126987,
#  'search': 208876,
#  'fresh': 93411,
#  'blood': 25060,
#  'enter': 75844,
#  'dr': 68579,
#  'helsing': 109690,
#  'able': 2803,
#  'vanquish': 251821,
#  'count': 50687,
#  'lawyer shows': 135094,
#  'shows vampire': 215181,
#  'vampire doorstep': 251626,
#  'doorstep falls': 68156,
#  'falls prey': 82103,
#  'prey charms': 185998,
#  'charms joins': 38420,
#  'joins search': 127040,
#  'search fresh': 208921,
#  'fresh blood': 93415,
#  'blood enter': 25084,
#  'enter dr': 75850,
#  'dr van': 68710,
#  'van helsing': 251732,
#  'helsing able': 109691,
#  'able vanquish': 2855,
#  'vanquish count': 251822,
#  'outcast': 172553,
#  'half': 105276,
#  'wolf': 261813,
#  'risks': 201313,
#  'epidemic': 76371,
#  'ravaging': 192671,
#  'nome': 167713,
#  'alaska': 7780,
#  'dog': 67291,
#  'hero': 109996,
#  'outcast half': 172559,
#  'half wolf': 105334,
#  'wolf risks': 261834,
#  'risks life': 201323,
#  'life prevent': 138963,
#  'prevent deadly': 185889,
#  'deadly epidemic': 57937,
#  'epidemic ravaging': 76379,
#  'ravaging nome': 192672,
#  'nome alaska': 167714,
#  'alaska dog': 7782,
#  'dog wolf': 67389,
#  'wolf hero': 261823,
#  'star': 223509,
#  'cast': 35369,
#  'epic': 76305,
#  'look': 143179,
#  'american': 9586,
#  'richard': 200364,
#  'nixon': 167571,
#  'carrying': 34906,
#  'fate': 83934,
#  'shoulders': 214968,
#  'battling': 20065,
#  'self': 210557,
#  'destructive': 62152,
#  'demands': 60463,
#  'spanning': 221255,
#  'troubled': 245252,
#  'boyhood': 27831,
#  'california': 32474,
#  'shocking': 214471,
#  'watergate': 257239,
#  'scandal': 207066,
#  'presidency': 185542,
#  'triumphant': 245024,
#  'victory': 253071,
#  'bitter': 24210,
#  'defeat': 59813,
#  'changed': 37539,
#  'lost': 144004,
#  'nation': 164216,
#  'star cast': 223534,
#  'cast powers': 35409,
#  'powers epic': 184680,
#  'epic look': 76337,
#  'look american': 143187,
#  'american president': 9805,
#  'president richard': 185610,
#  'richard nixon': 200407,
#  'nixon man': 167575,
#  'man carrying': 148593,
#  'carrying fate': 34916,
#  'fate world': 84036,
#  'world shoulders': 264518,
#  'shoulders battling': 214969,
#  'battling self': 20077,
#  'self destructive': 210581,
#  'destructive demands': 62160,
#  'demands spanning': 60489,
#  'spanning troubled': 221265,
#  'troubled boyhood': 245260,
#  'boyhood california': 27832,
#  'california shocking': 32540,
#  'shocking watergate': 214524,
#  'watergate scandal': 257240,
#  'scandal end': 207072,
#  'end presidency': 74610,
#  'presidency triumphant': 185548,
#  'triumphant victory': 245031,
#  'victory bitter': 253073,
#  'bitter defeat': 24215,
#  'defeat changed': 59820,
#  'changed world': 37583,
#  'world lost': 264301,
#  'lost nation': 144082,
#  'morgan': 159705,
#  'adams': 4732,
#  'slave': 217613,
#  'william': 260555,
#  'shaw': 213782,
#  'quest': 190531,
#  'recover': 194593,
#  'portions': 183661,
#  'treasure': 244019,
#  'map': 150027,
#  'unfortunately': 248988,
#  'portion': 183659,
#  'held': 108898,
#  'murderous': 162214,
#  'uncle': 247961,
#  'dawg': 57061,
#  'skeptical': 217173,
#  'leadership': 135443,
#  'abilities': 2737,
#  'complete': 46601,
#  'mutiny': 162916,
#  'difficult': 63862,
#  'efforts': 72561,
#  'british': 29391,
#  'crown': 53817,
#  'pirate': 180230,
#  'raids': 191684,
#  'course': 51416,
#  'turning': 246749,
#  'prepare': 185257,
#  'summon': 230508,
#  'courage': 51338,
#  'adventure': 5492,
#  'lifetime': 139407,
#  'morgan adams': 159706,
#  'adams slave': 4747,
#  'slave william': 217641,
#  'william shaw': 260593,
#  'shaw quest': 213788,
#  'quest recover': 190586,
#  'recover portions': 194612,
#  'portions treasure': 183662,
#  'treasure map': 244032,
#  'map unfortunately': 150054,
#  'unfortunately final': 249009,
#  'final portion': 87805,
#  'portion held': 183660,
#  'held murderous': 108916,
#  'murderous uncle': 162240,
#  'uncle dawg': 247983,
#  'dawg crew': 57062,
#  'crew skeptical': 52922,
#  'skeptical leadership': 217181,
#  'leadership abilities': 135444,
#  'abilities complete': 2739,
#  'complete quest': 46633,
#  'quest mutiny': 190573,
#  'mutiny difficult': 162918,
#  'difficult efforts': 63874,
#  'efforts british': 72564,
#  'british crown': 29424,
#  'crown end': 53821,
#  'end pirate': 74604,
#  'pirate raids': 180246,
#  'raids course': 191686,
#  'course set': 51480,
#  'set turning': 212386,
#  'turning prepare': 246774,
#  'prepare weapons': 185298,
#  'weapons summon': 258214,
#  'summon courage': 230510,
#  'courage discover': 51349,
#  'discover adventure': 64999,
#  'adventure lifetime': 5590,
#  'gambling': 95865,
#  'paradise': 174489,
#  'las': 134157,
#  'vegas': 252154,
#  'dark': 56027,
#  'mafia': 146896,
#  'underbelly': 248270,
#  'stays': 224823,
#  'forever': 91518,
#  'life gambling': 138599,
#  'gambling paradise': 95878,
#  'paradise las': 174502,
#  'las vegas': 134158,
#  'vegas dark': 252166,
#  'dark mafia': 56073,
#  'mafia underbelly': 146938,
#  'underbelly stays': 248271,
#  'stays forever': 224828,
#  'rich': 200270,
#  'mr': 161334,
#  'dashwood': 56281,
#  'dies': 63595,
#  'leaving': 136380,
#  'second': 209275,
#  'daughters': 56789,
#  'poor': 183296,
#  'rules': 204165,
#  'inheritance': 119849,
#  'titular': 240528,
#  'opposites': 171407,
#  'lose': 143764,
#  'come': 44634,
#  'senses': 211151,
#  'rich mr': 200335,
#  'mr dashwood': 161357,
#  'dashwood dies': 56282,
#  'dies leaving': 63636,
#  'leaving second': 136427,
#  'second wife': 209355,
#  'wife daughters': 259893,
#  'daughters poor': 56816,
#  'poor rules': 183341,
#  'rules inheritance': 204196,
#  'inheritance daughters': 119853,
#  'daughters titular': 56825,
#  'titular opposites': 240531,
#  'opposites lose': 171414,
#  'lose heart': 143786,
#  'heart come': 108252,
#  'come senses': 44808,
#  'ted': 235497,
#  'bellhop': 22068,
#  'night': 166997,
#  'job': 125994,
#  'hotel': 114270,
#  'unusual': 250263,
#  'guests': 104305,
#  'outrageous': 172732,
#  'predicaments': 185013,
#  'evening': 77788,
#  'service': 211982,
#  'serving': 212068,
#  'unbelievable': 247877,
#  'happening': 106211,
#  'scandalous': 207095,
#  'requests': 197667,
#  'lone': 142760,
#  'day': 57091,
#  'wildest': 260461,
#  'new': 165874,
#  'eve': 77710,
#  'ted bellhop': 235500,
#  'bellhop night': 22070,
#  'night job': 167131,
#  'job hotel': 126106,
#  'hotel unusual': 114340,
#  'unusual guests': 250282,
#  'guests place': 104330,
#  'place outrageous': 180561,
#  'outrageous predicaments': 172757,
#  'predicaments evening': 185014,
#  'evening room': 77824,
#  'room service': 203331,
#  'service serving': 212033,
#  'serving unbelievable': 212080,
#  'unbelievable happening': 247881,
#  'happening outrageous': 106231,
#  'outrageous guests': 172750,
#  'guests scandalous': 104332,
#  'scandalous requests': 207098,
#  'requests lone': 197669,
#  'lone bellhop': 142761,
#  'bellhop day': 22069,
#  'day job': 57260,
#  'job wildest': 126255,
#  'wildest new': 260470,
#  'new year': 166397,
#  'year eve': 265983,
#  'eve life': 77743,
#  'summoned': 230514,
#  'ashram': 14341,
#  'tibet': 239250,
#  'ace': 3835,
#  'finds': 88139,
#  'perilous': 178209,
#  'journey': 127450,
#  'jungles': 128193,
#  'africa': 6296,
#  'shikaka': 214155,
#  'missing': 157531,
#  'sacred': 205199,
#  'animal': 10969,
#  'friendly': 93911,
#  'wachati': 254952,
#  'tribe': 244345,
#  'accomplish': 3641,
#  'princess': 186289,
#  'prince': 186231,
#  'warrior': 256760,
#  'wachootoos': 254955,
#  'fails': 81607,
#  'result': 198637,
#  'vicious': 252818,
#  'tribal': 244336,
#  'war': 256139,
#  'animals': 11011,
#  'hair': 105183,
#  'summoned ashram': 230515,
#  'ashram tibet': 14343,
#  'tibet ace': 239251,
#  'ace finds': 3841,
#  'finds perilous': 88424,
#  'perilous journey': 178216,
#  'journey jungles': 127531,
#  'jungles africa': 128194,
#  'africa shikaka': 6332,
#  'shikaka missing': 214156,
#  'missing sacred': 157588,
#  'sacred animal': 205200,
#  'animal friendly': 10986,
#  'friendly wachati': 93939,
#  'wachati tribe': 254954,
#  'tribe accomplish': 244346,
#  'accomplish wedding': 3648,
#  'wedding wachati': 258485,
#  'wachati princess': 254953,
#  'princess prince': 186337,
#  'prince warrior': 186284,
#  'warrior wachootoos': 256809,
#  'wachootoos ace': 254956,
#  'ace fails': 3839,
#  'fails result': 81632,
#  'result vicious': 198683,
#  'vicious tribal': 252861,
#  'tribal war': 244344,
#  'war new': 256396,
#  'new animals': 165896,
#  'animals new': 11034,
#  'new adventures': 165884,
#  'adventures hair': 5706,
#  'vengeful': 252314,
#  'york': 266645,
#  'transit': 243418,
#  ...}

# %%
tfidf_matrix.shape # 9099개의 문장이 268124 토큰으로 표현됨
# Out:
# (9099, 268124)

# %%
print(np.array(tfidf_matrix)) # (m, n) xxx : 문장 m에서의 단어 n의 tfidf값
# Out:
#   (0, 14374)	0.12185152744271287
#   (0, 135999)	0.13497681053459026
#   (0, 78094)	0.13497681053459026
#   (0, 70735)	0.13497681053459026
#   (0, 173370)	0.13497681053459026
#   (0, 263028)	0.13497681053459026
#   (0, 32156)	0.13497681053459026
#   (0, 211426)	0.13497681053459026
#   (0, 40915)	0.13497681053459026
#   (0, 32149)	0.13497681053459026
#   (0, 182227)	0.13497681053459026
#   (0, 263030)	0.13497681053459026
#   (0, 108388)	0.13497681053459026
#   (0, 10561)	0.13497681053459026
#   (0, 180445)	0.13497681053459026
#   (0, 143950)	0.13497681053459026
#   (0, 6282)	0.13497681053459026
#   (0, 207239)	0.13497681053459026
#   (0, 139595)	0.13497681053459026
#   (0, 32153)	0.1291687802417233
#   (0, 29230)	0.13497681053459026
#   (0, 24049)	0.13497681053459026
#   (0, 10548)	0.13497681053459026
#   (0, 203273)	0.13497681053459026
#   (0, 106359)	0.13497681053459026
#   :	:
#   (9097, 137596)	0.048461572127086204
#   (9097, 239488)	0.05798939970295126
#   (9097, 52652)	0.050857909833882636
#   (9097, 78310)	0.0379398695854721
#   (9097, 263896)	0.02651436570868071
#   (9097, 29222)	0.0453986404335463
#   (9098, 16734)	0.2561682719130367
#   (9098, 51829)	0.2561682719130367
#   (9098, 4548)	0.2561682719130367
#   (9098, 58280)	0.2561682719130367
#   (9098, 82446)	0.2561682719130367
#   (9098, 232419)	0.2561682719130367
#   (9098, 8978)	0.2561682719130367
#   (9098, 112126)	0.2561682719130367
#   (9098, 51828)	0.2561682719130367
#   (9098, 112125)	0.2561682719130367
#   (9098, 16733)	0.23647723317395344
#   (9098, 232413)	0.20689144076310745
#   (9098, 93245)	0.24799575243656474
#   (9098, 8975)	0.2320980953901389
#   (9098, 28512)	0.1651072431436006
#   (9098, 93239)	0.1454162044045173
#   (9098, 58279)	0.1889226362193149
#   (9098, 4542)	0.19075605710816051
#   (9098, 82306)	0.09589205091419437

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim[0]
# 1 :첫번째 문장 자기자신과의 코사인 유사도
# 0.00680476 :첫번째 문장과 두 번째 문장과의 코사인 유사도
# Out:
# array([1.        , 0.00680476, 0.        , ..., 0.        , 0.00344913,
#        0.        ])

# %%
cosine_sim[9098]
# Out:
# array([0.        , 0.        , 0.00472155, ..., 0.        , 0.        ,
#        1.        ])

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])

# %%
smd
# Out:
#       index  adult  ...  year                                        description
# 0         0  False  ...  1995  Led by Woody, Andy's toys live happily in his ...
# 1         1  False  ...  1995  When siblings Judy and Peter discover an encha...
# 2         2  False  ...  1995  A family wedding reignites the ancient feud be...
# 3         3  False  ...  1995  Cheated on, mistreated and stepped on, the wom...
# 4         4  False  ...  1995  Just when George Banks has recovered from his ...
# ...     ...    ...  ...   ...                                                ...
# 9094  40224  False  ...  2016  From the mind behind Evangelion comes a hit la...
# 9095  40503  False  ...  2016  The band stormed Europe in 1963, and, in 1964,...
# 9096  44821  False  ...  2000  When Molly Hale's sadness of her father's disa...
# 9097  44826  False  ...  2001  All your favorite Pokémon characters are back,...
# 9098  45265  False  ...  2014  While holidaying in the French Alps, a Swedish...
#
# [9099 rows x 27 columns]

# %%
indices
# Out:
# title
# Toy Story                                                0
# Jumanji                                                  1
# Grumpier Old Men                                         2
# Waiting to Exhale                                        3
# Father of the Bride Part II                              4
#                                                       ...
# Shin Godzilla                                         9094
# The Beatles: Eight Days a Week - The Touring Years    9095
# Pokémon: Spell of the Unknown                         9096
# Pokémon 4Ever: Celebi - Voice of the Forest           9097
# Force Majeure                                         9098
# Length: 9099, dtype: int64

# %%
def get_recommendations(title):
  idx = indices[title] #해당 title 인덱스
  sim_scores = list(enumerate(cosine_sim[idx])) #해당 title 과 다른 영화와의 유사도 인덱싱
  # (1, 0.00282712634654008) :해당 title과 1번째 영화와의 유사도가 0.002827126346...
  sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) #유사도를 기준으로 내림차순으로 정렬
  sim_scores = sim_scores[1:31] #자기자신과의 유사도(1)을 제외하고, 유사도가 가장 높은 것부터 30개 추출
  movie_indices = [i[0] for i in sim_scores] #유사도 상위30개 영화에 대한 인덱스
  return titles.iloc[movie_indices]

# %%
list(enumerate(cosine_sim[indices['The Godfather']]))
# Out:
# [(0, 0.0),
#  (1, 0.00282712634654008),
#  (2, 0.013274406850346377),
#  (3, 0.0),
#  (4, 0.001911923808690747),
#  (5, 0.009831202255696751),
#  (6, 0.0),
#  (7, 0.0048937541840076175),
#  (8, 0.0),
#  (9, 0.007200486377613863),
#  (10, 0.0),
#  (11, 0.0),
#  (12, 0.002629662427098924),
#  (13, 0.01655348503181121),
#  (14, 0.0),
#  (15, 0.003311321356213731),
#  (16, 0.0),
#  (17, 0.0017852909522175192),
#  (18, 0.0),
#  (19, 0.0),
#  (20, 0.00138960229604634),
#  (21, 0.02347433335488712),
#  (22, 0.002909885967091068),
#  (23, 0.0),
#  (24, 0.0),
#  (25, 0.0),
#  (26, 0.0),
#  (27, 0.011643868586706513),
#  (28, 0.0),
#  (29, 0.056141832299658065),
#  (30, 0.0),
#  (31, 0.0028878395660696552),
#  (32, 0.0),
#  (33, 0.0),
#  (34, 0.0),
#  (35, 0.0038924168745627535),
#  (36, 0.0),
#  (37, 0.0),
#  (38, 0.02717387932966191),
#  (39, 0.0),
#  (40, 0.0),
#  (41, 0.0020748439693151896),
#  (42, 0.0),
#  (43, 0.0),
#  (44, 0.002612852388514977),
#  (45, 0.0),
#  (46, 0.01116205834731158),
#  (47, 0.0),
#  (48, 0.017220777855400132),
#  (49, 0.003365386412223826),
#  (50, 0.006507663461137723),
#  (51, 0.006631895381637897),
#  (52, 0.0),
#  (53, 0.006437279085166214),
#  (54, 0.013040187304503736),
#  (55, 0.0),
#  (56, 0.002830529896513966),
#  (57, 0.0),
#  (58, 0.0016341710447209138),
#  (59, 0.001336823001455865),
#  (60, 0.0),
#  (61, 0.005571864499865456),
#  (62, 0.0054085125464932654),
#  (63, 0.0),
#  (64, 0.0),
#  (65, 0.008720246245398166),
#  (66, 0.0),
#  (67, 0.0014885224573990786),
#  (68, 0.001817306454800401),
#  (69, 0.0),
#  (70, 0.0017605504862671035),
#  (71, 0.008247689534620005),
#  (72, 0.003838492577499594),
#  (73, 0.0035435309561023236),
#  (74, 0.0),
#  (75, 0.0),
#  (76, 0.005663211820821277),
#  (77, 0.005448502124455453),
#  (78, 0.015901594474569587),
#  (79, 0.009871792566223487),
#  (80, 0.0),
#  (81, 0.014629266154415344),
#  (82, 0.015537330677950958),
#  (83, 0.0),
#  (84, 0.0),
#  (85, 0.0),
#  (86, 0.012885600575678585),
#  (87, 0.0),
#  (88, 0.0),
#  (89, 0.0),
#  (90, 0.0),
#  (91, 0.0),
#  (92, 0.0),
#  (93, 0.010113960778707574),
#  (94, 0.0),
#  (95, 0.0),
#  (96, 0.0),
#  (97, 0.0021714602737906816),
#  (98, 0.0),
#  (99, 0.0),
#  (100, 0.0),
#  (101, 0.0),
#  (102, 0.0),
#  (103, 0.007179322068415218),
#  (104, 0.0),
#  (105, 0.004907100803671469),
#  (106, 0.0017059891295564944),
#  (107, 0.002007071937773976),
#  (108, 0.0072453897624824674),
#  (109, 0.0),
#  (110, 0.0),
#  (111, 0.001518603393308597),
#  (112, 0.0),
#  (113, 0.00700719842299213),
#  (114, 0.0),
#  (115, 0.004726494693686941),
#  (116, 0.005168117862895506),
#  (117, 0.0),
#  (118, 0.0),
#  (119, 0
#  (4998, 0.009036230191245628),
#  (7648, 0.009027712590146831),
#  (6019, 0.009023751539185158),
#  (8209, 0.009010718552302056),
#  (5389, 0.009009789393697632),
#  (2579, 0.009005675213391058),
#  (8358, 0.009003924892053618),
#  (8547, 0.008989160326559846),
#  (4885, 0.008983901490392108),
#  (2604, 0.008982470310987855),
#  (2363, 0.008980556449445261),
#  (7783, 0.008973094811807825),
#  (5415, 0.008973043957166024),
#  (7024, 0.00896973390051183),
#  (1090, 0.008966459186272487),
#  (1876, 0.008952135473611542),
#  (3580, 0.008948520744602739),
#  (7692, 0.008929337348011431),
#  (5925, 0.008929309606543898),
#  (781, 0.008928980377051572),
#  (4401, 0.008927265817647084),
#  (8371, 0.008917137970228625),
#  (6544, 0.008910185963674174),
#  (6476, 0.008905520793739425),
#  (780, 0.008896001037192233),
#  (460, 0.008886869359247746),
#  (2950, 0.008868867531864595),
#  (5814, 0.008862491062679471),
#  (9054, 0.00886139519035857),
#  (2899, 0.00885766959413307),
#  (4709, 0.008853628209378787),
#  (331, 0.00885341388273581),
#  (2474, 0.008847286729842474),
#  (2170, 0.008836965858838615),
#  (7926, 0.008836166184064858),
#  (4400, 0.008818310873040492),
#  (5138, 0.008802566373244381),
#  (7533, 0.008795326100096524),
#  (4188, 0.008794136671642201),
#  (5126, 0.00877590355357844),
#  (1113, 0.008772572718432564),
#  (6604, 0.008770376784696518),
#  (7553, 0.008761311415807323),
#  (807, 0.008755707659405065),
#  ...]

# %%
get_recommendations('The Godfather').head(10)
# Out:
# 973      The Godfather: Part II
# 8387                 The Family
# 3509                       Made
# 4196         Johnny Dangerously
# 29               Shanghai Triad
# 5667                       Fury
# 2412             American Movie
# 1582    The Godfather: Part III
# 4221                    8 Women
# 2159              Summer of Sam
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight').head(10)
# Out:
# 7931                      The Dark Knight Rises
# 132                              Batman Forever
# 1113                             Batman Returns
# 8227    Batman: The Dark Knight Returns, Part 2
# 7565                 Batman: Under the Red Hood
# 524                                      Batman
# 7901                           Batman: Year One
# 2579               Batman: Mask of the Phantasm
# 2696                                        JFK
# 8165    Batman: The Dark Knight Returns, Part 1
# Name: title, dtype: object

# %% [markdown]
# Metadata Based Recommender

# %%
credits = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MovieRcmmd/data/data/credits.csv')
keywords = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MovieRcmmd/data/data/keywords.csv')

# %%
keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')
md['id'] = md['id'].astype('int')

# %%
keywords.head() # 각 영화의 keywords 정리
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
credits.head()
# cast :주연들에 대한 설명(character, name, gender,,)
# crew : 감독, 작가 등에 대한 설명
# Out:
#                                                 cast  ...     id
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...  ...    862
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...  ...   8844
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...  ...  15602
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...  ...  31357
# 4  [{'cast_id': 1, 'character': 'George Banks', '...  ...  11862
#
# [5 rows x 3 columns]

# %%
md.shape
# Out:
# (45463, 25)

# %%
md = md.merge(credits, on='id')
md = md.merge(keywords, on='id')
md.head()
# Out:
#    adult  ...                                           keywords
# 0  False  ...  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  False  ...  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  False  ...  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  False  ...  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  False  ...  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
#
# [5 rows x 28 columns]

# %%
smd = md[md['id'].isin(links_small)]
smd.shape
# Out:
# (9219, 28)

# %%
smd['cast'] = smd['cast'].apply(literal_eval)
smd['crew'] = smd['crew'].apply(literal_eval)
smd['keywords'] = smd['keywords'].apply(literal_eval)
smd['cast_size'] = smd['cast'].apply(lambda x: len(x))
smd['crew_size'] = smd['crew'].apply(lambda x: len(x))

# %%
def get_director(x):
  for i in x:
    if i['job'] == 'Director':
      return i['name']
  return np.nan

# %%
smd['director'] = smd['crew'].apply(get_director)

# %%
smd['cast'] = smd['cast'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
smd['cast'] = smd['cast'].apply(lambda x: x[:3] if len(x) >=3 else x) #주연이름 세자리까지만

# %%
smd['keywords'] = smd['keywords'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
smd['cast'] = smd['cast'].apply(lambda x: [str.lower(i.replace(" ","")) for i in x]) # 주연이름 붙여쓰기, 소문자로

# %%
smd['cast'].head()
# Out:
# 0                  [tomhanks, timallen, donrickles]
# 1       [robinwilliams, jonathanhyde, kirstendunst]
# 2          [waltermatthau, jacklemmon, ann-margret]
# 3    [whitneyhouston, angelabassett, lorettadevine]
# 4           [stevemartin, dianekeaton, martinshort]
# Name: cast, dtype: object

# %%
smd['director'] = smd['director'].astype('str').apply(lambda x: str.lower(x.replace(" ", "")))
smd['director'] = smd['director'].apply(lambda x: [x, x, x])

# %%
smd['director']
# Out:
# 0               [johnlasseter, johnlasseter, johnlasseter]
# 1                  [joejohnston, joejohnston, joejohnston]
# 2               [howarddeutch, howarddeutch, howarddeutch]
# 3         [forestwhitaker, forestwhitaker, forestwhitaker]
# 4               [charlesshyer, charlesshyer, charlesshyer]
#                                ...
# 40952        [greggchampion, greggchampion, greggchampion]
# 41172    [tinusureshdesai, tinusureshdesai, tinusureshd...
# 41225    [ashutoshgowariker, ashutoshgowariker, ashutos...
# 41391              [hideakianno, hideakianno, hideakianno]
# 41669                    [ronhoward, ronhoward, ronhoward]
# Name: director, Length: 9219, dtype: object

# %% [markdown]
# Keywords

# %%
s = smd.apply(lambda x: pd.Series(x['keywords']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'keyword'
s
# Out:
# 0           jealousy
# 0                toy
# 0                boy
# 0         friendship
# 0            friends
#             ...
# 41391    destruction
# 41391          kaiju
# 41391          toyko
# 41669          music
# 41669    documentary
# Name: keyword, Length: 64407, dtype: object

# %%
s = s.value_counts()
s[:5]
# Out:
# independent film        610
# woman director          550
# murder                  399
# duringcreditsstinger    327
# based on novel          318
# Name: keyword, dtype: int64

# %%
s = s[s > 1]

# %%
stemmer = SnowballStemmer('english') #접사 제거, 명사 추출
stemmer.stem('dogs')
# Out:
# 'dog'

# %%
def filter_keywords(x):
  words = []
  for i in x:
    if i in s:
      words.append(i)
  return words

# %%
smd['keywords'] = smd['keywords'].apply(filter_keywords)
smd['keywords']
# Out:
# 0        [jealousy, toy, boy, friendship, friends, riva...
# 1        [board game, disappearance, based on children'...
# 2             [fishing, best friend, duringcreditsstinger]
# 3        [based on novel, interracial relationship, sin...
# 4        [baby, midlife crisis, confidence, aging, daug...
#                                ...
# 40952                                         [friendship]
# 41172                                          [bollywood]
# 41225                                          [bollywood]
# 41391    [monster, godzilla, giant monster, destruction...
# 41669                                 [music, documentary]
# Name: keywords, Length: 9219, dtype: object

# %%
smd['keywords'] = smd['keywords'].apply(lambda x: [stemmer.stem(i) for i in x])
smd['keywords'] = smd['keywords'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %%
smd['keywords']
# Out:
# 0        [jealousi, toy, boy, friendship, friend, rival...
# 1        [boardgam, disappear, basedonchildren'sbook, n...
# 2                   [fish, bestfriend, duringcreditssting]
# 3        [basedonnovel, interracialrelationship, single...
# 4        [babi, midlifecrisi, confid, age, daughter, mo...
#                                ...
# 40952                                         [friendship]
# 41172                                          [bollywood]
# 41225                                          [bollywood]
# 41391     [monster, godzilla, giantmonst, destruct, kaiju]
# 41669                                 [music, documentari]
# Name: keywords, Length: 9219, dtype: object

# %%
smd['soup'] = smd['keywords'] + smd['cast'] + smd['director'] + smd['genres']
smd['soup'] = smd['soup'].apply(lambda x: ' '.join(x))
smd['soup']
# Out:
# 0        jealousi toy boy friendship friend rivalri boy...
# 1        boardgam disappear basedonchildren'sbook newho...
# 2        fish bestfriend duringcreditssting waltermatth...
# 3        basedonnovel interracialrelationship singlemot...
# 4        babi midlifecrisi confid age daughter motherda...
#                                ...
# 40952    friendship sidneypoitier wendycrewson jayo.san...
# 41172    bollywood akshaykumar ileanad'cruz eshagupta t...
# 41225    bollywood hrithikroshan poojahegde kabirbedi a...
# 41391    monster godzilla giantmonst destruct kaiju hir...
# 41669    music documentari paulmccartney ringostarr joh...
# Name: soup, Length: 9219, dtype: object

# %%
count = CountVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
count_matrix = count.fit_transform(smd['soup'])

# %%
count_matrix.shape # 9212개의 문장이 100304 토큰으로 표현
# Out:
# (9219, 107377)

# %%
print(np.array(count_matrix))
# Out:
#   (0, 48201)	1
#   (0, 99578)	1
#   (0, 11703)	1
#   (0, 35554)	1
#   (0, 35478)	1
#   (0, 82467)	1
#   (0, 11769)	1
#   (0, 70474)	1
#   (0, 99598)	1
#   (0, 98820)	1
#   (0, 98078)	1
#   (0, 26723)	1
#   (0, 51067)	3
#   (0, 4568)	1
#   (0, 19542)	1
#   (0, 32156)	1
#   (0, 48271)	1
#   (0, 99581)	1
#   (0, 11714)	1
#   (0, 35590)	1
#   (0, 35536)	1
#   (0, 82470)	1
#   (0, 11771)	1
#   (0, 70475)	1
#   (0, 99608)	1
#   :	:
#   (9217, 106919)	1
#   (9217, 86548)	1
#   (9217, 38388)	1
#   (9217, 37878)	1
#   (9217, 25096)	1
#   (9217, 53526)	1
#   (9217, 41960)	1
#   (9217, 106920)	1
#   (9217, 86549)	1
#   (9217, 41617)	1
#   (9218, 68585)	2
#   (9218, 26187)	1
#   (9218, 84440)	3
#   (9218, 84450)	2
#   (9218, 26197)	1
#   (9218, 26178)	1
#   (9218, 51095)	1
#   (9218, 74590)	1
#   (9218, 82382)	1
#   (9218, 68642)	1
#   (9218, 26185)	1
#   (9218, 74598)	1
#   (9218, 82384)	1
#   (9218, 51098)	1
#   (9218, 84444)	1

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim
# Out:
# array([[1.        , 0.02441931, 0.02738955, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02441931, 1.        , 0.        , ..., 0.02973505, 0.02500782,
#         0.        ],
#        [0.02738955, 0.        , 1.        , ..., 0.03335187, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.02973505, 0.03335187, ..., 1.        , 0.08700222,
#         0.        ],
#        [0.        , 0.02500782, 0.        , ..., 0.08700222, 1.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
smd = smd.reset_index()
titles = smd['title']
indices = pd.Series(smd.index, index=smd['title'])
indices
# Out:
# title
# Toy Story                                                0
# Jumanji                                                  1
# Grumpier Old Men                                         2
# Waiting to Exhale                                        3
# Father of the Bride Part II                              4
#                                                       ...
# The Last Brickmaker in America                        9214
# Rustom                                                9215
# Mohenjo Daro                                          9216
# Shin Godzilla                                         9217
# The Beatles: Eight Days a Week - The Touring Years    9218
# Length: 9219, dtype: int64

# %%
get_recommendations('The Dark Knight').head(10)
# Out:
# 8031         The Dark Knight Rises
# 6218                 Batman Begins
# 6623                  The Prestige
# 2085                     Following
# 7648                     Inception
# 4145                      Insomnia
# 3381                       Memento
# 8613                  Interstellar
# 7659    Batman: Under the Red Hood
# 1134                Batman Returns
# Name: title, dtype: object

# %%
get_recommendations('Mean Girls').head(10)
# Out:
# 3319               Head Over Heels
# 4763                 Freaky Friday
# 1329              The House of Yes
# 6277              Just Like Heaven
# 7905         Mr. Popper's Penguins
# 7332    Ghosts of Girlfriends Past
# 6959     The Spiderwick Chronicles
# 8883                      The DUFF
# 6698         It's a Boy Girl Thing
# 7377       I Love You, Beth Cooper
# Name: title, dtype: object

# %% [markdown]
# Popularity and Ratings

# %%
def improved_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = smd.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year']]
    vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')
    vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')
    C = vote_averages.mean()
    m = vote_counts.quantile(0.60)
    qualified = movies[(movies['vote_count'] >= m) & (movies['vote_count'].notnull()) & (movies['vote_average'].notnull())]
    qualified['vote_count'] = qualified['vote_count'].astype('int')
    qualified['vote_average'] = qualified['vote_average'].astype('int')
    qualified['wr'] = qualified.apply(weighted_rating, axis=1)
    qualified = qualified.sort_values('wr', ascending=False).head(10)
    return qualified

# %%
improved_recommendations('The Dark Knight')
# Out:
#                                    title  vote_count  ...  year        wr
# 7648                           Inception       14075  ...  2010  7.917588
# 8613                        Interstellar       11187  ...  2014  7.897107
# 6623                        The Prestige        4510  ...  2006  7.758148
# 3381                             Memento        4168  ...  2000  7.740175
# 8031               The Dark Knight Rises        9263  ...  2012  6.921448
# 6218                       Batman Begins        7511  ...  2005  6.904127
# 1134                      Batman Returns        1706  ...  1992  5.846862
# 132                       Batman Forever        1529  ...  1995  5.054144
# 9024  Batman v Superman: Dawn of Justice        7189  ...  2016  5.013943
# 1260                      Batman & Robin        1447  ...  1997  4.287233
#
# [10 rows x 5 columns]

# %%
improved_recommendations('Mean Girls')
# Out:
#                                         title  vote_count  ...  year        wr
# 1547                       The Breakfast Club        2189  ...  1985  6.709602
# 390                        Dazed and Confused         588  ...  1993  6.254682
# 8883                                 The DUFF        1372  ...  2015  5.818541
# 3712                     The Princess Diaries        1063  ...  2001  5.781086
# 4763                            Freaky Friday         919  ...  2003  5.757786
# 6277                         Just Like Heaven         595  ...  2005  5.681521
# 6959                The Spiderwick Chronicles         593  ...  2008  5.680901
# 7494  American Pie Presents: The Book of Love         454  ...  2009  5.119690
# 7332               Ghosts of Girlfriends Past         716  ...  2009  5.092422
# 7905                    Mr. Popper's Penguins         775  ...  2011  5.087912
#
# [10 rows x 5 columns]

# %% [markdown]
# Collaborative Filtering

# %%
reader = Reader()

# %%
ratings = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MovieRcmmd/data/data/ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader) #데이터셋 로딩

# %%
svd = SVD() # SVD :특이값 분해 알고리즘
kf = KFold(n_splits = 5)
